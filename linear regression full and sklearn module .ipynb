# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('C:\\Users\\Lenovo\\Downloads\\sai mahesh - bitcoin.CSV')
df["Close"].fillna(0,inplace=True)
df["Open"].fillna(0,inplace=True)
l=list(df["Date"])
l2=list(df["Close"]-df["Open"])
plt.plot(l,l2,"ro-")
plt.xlabel("date")
plt.ylabel(" Gross profit or loss")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('C:\\Users\\Lenovo\\Downloads\\sai mahesh - winequality.CSV')
df.head()
l1=df.quality.unique()
l2=list(df["quality"])
l=[]
for i in l1:
    l.append(l2.count(i))
print(l1,l)
plt.bar(l1,l,width=0.5)
plt.show()
# Out:
# [5 6 7 4 8 3] [681, 638, 199, 53, 18, 10]

# %%
import numpy as np
import matplotlib.pyplot as mp
import pandas as pd
from sklearn import linear_model
from sklearn.datasets import make_regression

# %%
x,y=make_regression(n_samples=20,bias=50,n_features=1,n_targets=1,noise=4.0,random_state=235)
mp.plot(x,y,'.')
mp.grid(True)
mp.show()

# %%
#mp.grid(True or False)

# %%
x,y=make_regression(n_samples=20,bias=50,n_features=1,n_targets=1,noise=4.0,random_state=235)
mp.plot(x,y,'.')
mp.grid(True,alpha=0.5)
mp.show()
